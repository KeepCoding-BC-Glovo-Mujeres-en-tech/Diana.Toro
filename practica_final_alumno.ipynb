# %% [markdown]
# # **Practica Python para Big Data**
# **Diana María Toro López**

# %%
import pandas as pd

# %% [markdown]
# Cargar datos

# %%
# Importamos el dataset de los datos de los pokemon
# No especifico el delimiter porque por defecto es coma
df = pd.read_csv('dataset_final.csv') 
# Devuelve las n primeras 5 filas del DataFrame
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# Como primera medida quiero ordenar la primera fila, para poder hacer uso de las funciones segun mi conveniencia
# Se renombran los títulos
df = df.rename(columns={'#':'No', 'Type 1':'Type_1', 'Type 2':'Type_2', 'Sp. Atk':'Sp_Atk', 'Sp. Def':'Sp_Def'})

# %%
'''
1. ¿Cuántos pokémon hay en el dataset?
'''
# df.No.count()
print(f'En el dataset hay \033[1m{df.No.count()}\033[0m pokémon.')
# Out:
# En el dataset hay 800 pokémon.

# %%
'''
2. ¿Cuántos pokémon hay de tipo Poison? (Type 1)
'''
tipo_Poison = df['Type_1'] == 'Poison'
df[tipo_Poison]
# Otra Forma de hacerlo
# df.groupby('Type_1').get_group('Poison')
# Out:
#       No       Name  Type_1    Type_2  Total   HP  Attack  Defense  Sp_Atk  \
# 28    23      Ekans  Poison       NaN    288   35      60       44      40
# 29    24      Arbok  Poison       NaN    438   60      85       69      65
# 34    29   Nidoran♀  Poison       NaN    275   55      47       52      40
# 35    30   Nidorina  Poison       NaN    365   70      62       67      55
# 36    31  Nidoqueen  Poison    Ground    505   90      92       87      75
# 37    32   Nidoran♂  Poison       NaN    273   46      57       40      40
# 38    33   Nidorino  Poison       NaN    365   61      72       57      55
# 39    34   Nidoking  Poison    Ground    505   81     102       77      85
# 46    41      Zubat  Poison    Flying    245   40      45       35      30
# 47    42     Golbat  Poison    Flying    455   75      80       70      65
# 95    88     Grimer  Poison       NaN    325   80      80       50      40
# ...

# %%
cantidad = df[tipo_Poison].Type_1.count()
print(f'Hay \033[1m{cantidad}\033[0m pokémon de tipo Poison.')
# Out:
# Hay 28 pokémon de tipo Poison.

# %%
'''
3. ¿Cuántos tipos diferentes de pokémon hay? (Type 1)
'''
# Otra forma de hacerlo
# df.groupby('Type_1').Name.nunique()

# value_counts(), devuelve una serie que contiene recuentos de valores únicos
# count(), cuenta cuantos valores unicos hay
cantidad = df.Type_1.value_counts().count()
print(f'Hay \033[1m{cantidad}\033[0m tipos de pokémon diferentes en el dataset.')
# Out:
# Hay 18 tipos de pokémon diferentes en el dataset.

# %%
'''
2. ¿Cuántos pokémon hay de cada tipo? (Type 1)
'''
# df.Type_1.value_counts().sort_values(ascending=True)

sep = '='*18
print(f'\033[1m{sep}\nPokemon   Cantidad\n{sep}\033[0m')
df.Type_1.value_counts().sort_values(ascending=True)
# Out:
# ...
# Pokemon   Cantidad
# ...
# Flying        4
# Fairy        17
# Ice          24
# Fighting     27
# Steel        27
# Poison       28
# Dark         31
# Ghost        32
# Ground       32
# Dragon       32
# Electric     44
# Rock         44
# Fire         52
# Psychic      57
# Bug          69
# Grass        70
# Normal       98
# Water       112
# Name: Type_1, dtype: int64

# %%
'''
2.1 ¿cual es el tipo de pokémon con más pokémon? (Type 1)
'''
tipo = df.Type_1.max()
print(f'El tipo de pokémon con más pokémon es: \033[1m{tipo}\033[0m.')
# Out:
# El tipo de pokémon con más pokémon es: Water.

# %%
'''
3. ¿Cuál es el pokémon más rápido?
'''
mayor_velocidad = df.Speed.max()
mas_rapido = df.groupby('Speed').get_group(mayor_velocidad)
mas_rapido
# Out:
#       No               Name   Type_1 Type_2  Total  HP  Attack  Defense  \
# 431  386  DeoxysSpeed Forme  Psychic    NaN    600  50      95       90
#
#      Sp_Atk  Sp_Def  Speed  Generation  Legendary
# 431      95      90    180           3       True

# %%
# Para mostrar respuesta
from functools import reduce
nombre = ''
# convertimos el resultado de extraer el nombre del pokemón más veloz, en este caso es uno, pero puede haber el caso
# de varios pokemon con la misma velocidad, por tal razon se itera una lista y los nombres se convierten a String
nombre = reduce(lambda x: str(x), mas_rapido.Name.values)
print(f'El pokemosn más rapido es \033[1m{nombre}\033[0m.')
# Out:
# El pokemosn más rapido es DeoxysSpeed Forme.

# %%
'''
4. ¿Cuántos pokemon tiene una defensa inferior a 100?
'''
menor_igual_100 = df.Defense <= 100
cantidad = df[menor_igual_100].Defense.count()

print(f'Hay \033[1m{cantidad}\033[0m pokemon con una defensa inferior a 100.')

# Otra Manera de hacerlo tanto para visulizar datos como para sacar cantidades
# valores = df.query('Defense <= 100').count()
# Out:
# Hay 677 pokemon con una defensa inferior a 100.

# %%
'''
4.1 ¿Cuántos pokemon tiene una defensa superior o igual a 100?
'''
mayor_100 = df.Defense > 100
cantidad = df[mayor_100].Defense.count()

print(f'Hay \033[1m{cantidad}\033[0m pokemon con una defensa superior a 100.')

# Otra Manera de hacerlo tanto para visulizar datos como para sacar cantidades
# valores = df.query('Defense > 100').count()
# Out:
# Hay 123 pokemon con una defensa superior a 100.

# %%
'''
5. ¿Cuántos pokemon tiene una defensa superior a 100 y una velocidad superior a 100?
'''
defensa_100 = df.Defense > 100
speed_100 = df.Speed > 100
df[defensa_100 & speed_100]
cantidad = df[defensa_100 & speed_100].Defense.count()

print(f'Hay \033[1m{cantidad}\033[0m pokemon con defensa y velocidad superior a 100')
# Out:
# Hay 9 pokemon con defensa y velocidad superior a 100

# %%
'''
6. Ordena el dataset por el tipo 1 y por el tipo 2
'''
print('\033[1mDATAFRAME ORDENADO:\033[0m')
df.sort_values(['Type_1', 'Type_2'])

# Otra forma de ordenar
# df.sort_values(by = ['Type_1', 'Type_2'], ascending = [True, False], na_position = 'first')
# Out:
# DATAFRAME ORDENADO:
#       No                     Name Type_1    Type_2  Total   HP  Attack  \
# 656  595                   Joltik    Bug  Electric    319   50      47
# 657  596               Galvantula    Bug  Electric    472   70      77
# 231  214                Heracross    Bug  Fighting    500   80     125
# 232  214  HeracrossMega Heracross    Bug  Fighting    600   80     185
# 697  636                 Larvesta    Bug      Fire    360   55      85
# ..   ...                      ...    ...       ...    ...  ...     ...
# 655  594                Alomomola  Water       NaN    470  165      75
# 724  656                  Froakie  Water       NaN    314   41      56
# 725  657                Frogadier  Water       NaN    405   54      63
# 762  692                Clauncher  Water       NaN    330   50      53
# 763  693                Clawitzer  Water       NaN    500   71      73
#
#      Defense  Sp_Atk  Sp_Def  Speed  Generation  Legendary
# ...

# %%
'''
7. Crea un nuevo dataset con los pokémon de tipo Water y Fire como primer tipo
'''
import numpy as np
agua_fuego = df[df.Type_1.isin(['Fire', 'Water'])]
# Extraigo el tamaño del dataset para asignar la numeracion de la columna No
tamaño = agua_fuego.shape
# Actualizo la columna No
agua_fuego.No = np.arange(tamaño[0])

# %%
agua_fuego
# Out:
#       No                       Name Type_1  Type_2  Total  HP  Attack  \
# 4      0                 Charmander   Fire     NaN    309  39      52
# 5      1                 Charmeleon   Fire     NaN    405  58      64
# 6      2                  Charizard   Fire  Flying    534  78      84
# 7      3  CharizardMega Charizard X   Fire  Dragon    634  78     130
# 8      4  CharizardMega Charizard Y   Fire  Flying    634  78     104
# ..   ...                        ...    ...     ...    ...  ..     ...
# 735  159                     Litleo   Fire  Normal    369  62      50
# 736  160                     Pyroar   Fire  Normal    507  86      68
# 762  161                  Clauncher  Water     NaN    330  50      53
# 763  162                  Clawitzer  Water     NaN    500  71      73
# 799  163                  Volcanion   Fire   Water    600  80     110
#
#      Defense  Sp_Atk  Sp_Def  Speed  Generation  Legendary
# 4         43      60      50     65           1      False
# ...

# %%
agua_fuego.to_csv('agua_fuego.csv', index=False)

# %%
'''
8. Crea un nuevo dataset con los pokemon Legendary
'''
legendary = df[df.Legendary.isin([True])]
tamaño = legendary.shape
legendary.No = np.arange(tamaño[0])

# %%
legendary
# Out:
#      No                 Name    Type_1    Type_2  Total   HP  Attack  Defense  \
# 156   0             Articuno       Ice    Flying    580   90      85      100
# 157   1               Zapdos  Electric    Flying    580   90      90       85
# 158   2              Moltres      Fire    Flying    580   90     100       90
# 162   3               Mewtwo   Psychic       NaN    680  106     110       90
# 163   4  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100
# ..   ..                  ...       ...       ...    ...  ...     ...      ...
# 795  60              Diancie      Rock     Fairy    600   50     100      150
# 796  61  DiancieMega Diancie      Rock     Fairy    700   50     160      110
# 797  62  HoopaHoopa Confined   Psychic     Ghost    600   80     110       60
# 798  63   HoopaHoopa Unbound   Psychic      Dark    680   80     160       60
# 799  64            Volcanion      Fire     Water    600   80     110      120
#
# ...

# %%
legendary.to_csv('legendary.csv', index=False)

# %%
'''
9. Calcula el promedio de stats de los pokemon Legendary 
(HP, Attack, Defense, Sp. Atk, Sp. Def, Speed)
'''
hp = legendary['HP'].mean()
attack = legendary['Attack'].mean()
defense = legendary['Defense'].mean()
sp_atk = legendary['Sp_Atk'].mean()
sp_def = legendary['Sp_Def'].mean()
speed = legendary['Speed'].mean()

print(f'El promedio \033[1mHP\033[0m para Legendary es: \033[1m{round(hp,2)}.\033[0m')
print(f'El promedio \033[1mAttack\033[0m para Legendary es: \033[1m{round(attack,2)}.\033[0m')
print(f'El promedio \033[1mDefense\033[0m para Legendary es: \033[1m{round(defense,2)}.\033[0m')
print(f'El promedio \033[1mSp_Atk\033[0m para Legendary es: \033[1m{round(sp_atk,2)}.\033[0m')
print(f'El promedio \033[1mSp_Def\033[0m para Legendary es: \033[1m{round(sp_def,2)}.\033[0m')
print(f'El promedio \033[1mSpeed\033[0m para Legendary es: \033[1m{round(speed,2)}.\033[0m')
# Out:
# El promedio HP para Legendary es: 92.74.
# El promedio Attack para Legendary es: 116.68.
# El promedio Defense para Legendary es: 99.66.
# El promedio Sp_Atk para Legendary es: 122.18.
# El promedio Sp_Def para Legendary es: 105.94.
# El promedio Speed para Legendary es: 100.18.

# %%
# los no Legendary
no_legendary = df[df.Legendary.isin([False])]
tamaño = no_legendary.shape
no_legendary.No = np.arange(tamaño[0])

# %%
no_legendary
# Out:
#       No                   Name  Type_1  Type_2  Total  HP  Attack  Defense  \
# 0      0              Bulbasaur   Grass  Poison    318  45      49       49
# 1      1                Ivysaur   Grass  Poison    405  60      62       63
# 2      2               Venusaur   Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur   Grass  Poison    625  80     100      123
# 4      4             Charmander    Fire     NaN    309  39      52       43
# ..   ...                    ...     ...     ...    ...  ..     ...      ...
# 787  730    GourgeistSuper Size   Ghost   Grass    494  85     100      122
# 788  731               Bergmite     Ice     NaN    304  55      69       85
# 789  732                Avalugg     Ice     NaN    514  95     117      184
# 790  733                 Noibat  Flying  Dragon    245  40      30       35
# 791  734                Noivern  Flying  Dragon    535  85      70       80
#
# ...

# %%
hp = no_legendary['HP'].mean()
attack = no_legendary['Attack'].mean()
defense = no_legendary['Defense'].mean()
sp_atk = no_legendary['Sp_Atk'].mean()
sp_def = no_legendary['Sp_Def'].mean()
speed = no_legendary['Speed'].mean()

print(f'El promedio \033[1mHP\033[0m para no Legendary es: \033[1m{round(hp,2)}.\033[0m')
print(f'El promedio \033[1mAttack\033[0m para no Legendary es: \033[1m{round(attack,2)}.\033[0m')
print(f'El promedio \033[1mDefense\033[0m para no Legendary es: \033[1m{round(defense,2)}.\033[0m')
print(f'El promedio \033[1mSp_Atk\033[0m para no Legendary es: \033[1m{round(sp_atk,2)}.\033[0m')
print(f'El promedio \033[1mSp_Def\033[0m para no Legendary es: \033[1m{round(sp_def,2)}.\033[0m')
print(f'El promedio \033[1mSpeed\033[0m para no Legendary es: \033[1m{round(speed,2)}.\033[0m')
# Out:
# El promedio HP para no Legendary es: 67.18.
# El promedio Attack para no Legendary es: 75.67.
# El promedio Defense para no Legendary es: 71.56.
# El promedio Sp_Atk para no Legendary es: 68.45.
# El promedio Sp_Def para no Legendary es: 68.89.
# El promedio Speed para no Legendary es: 65.46.

# %%
'''
10. Crea un nuevo dataframe con el resultado del anterior ejercicio comparando ambos promedios

ejemplo:
                HP  Attack  Defense  Sp_Atk  Sp_Def  Speed
Legendary       99      90       89       91       94     90
No_Legendary    80      95       75       12       43     87

'''
d = { 'POKEMON': ['Legendary', 'No_Legendary'],
            'HP': [92.74, 67.18], 
            'Attack': [116.68, 75.67],
            'Defense': [99.66, 71.56],
            'Sp_Atk': [122.18, 68.45],
            'Sp_Def': [105.94, 68.89],
            'Speed': [100.18, 65.46]
          }
new_df = pd.DataFrame(data=d)
new_df
# Out:
#         POKEMON     HP  Attack  Defense  Sp_Atk  Sp_Def   Speed
# 0     Legendary  92.74  116.68    99.66  122.18  105.94  100.18
# 1  No_Legendary  67.18   75.67    71.56   68.45   68.89   65.46

# %%
'''
11. Añade una nueva colunma ['Doble tipo'] al dataframe inicial que inndique si el pokemo tiene dos tipos o no
'''
# visualizo el df inicial
df
# Out:
#       No                   Name   Type_1  Type_2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# Obtengo los valores unicos de Type_1
nombre1 = df.Type_1.value_counts()
# Convierto a diccionario el resultado
nombre1 = dict(nombre1)
# Extraigo las claves y las asigno a una lista
rango1 = list(nombre1.keys())
# a valor1 asigno un booleano True encuentra el valor unico en la celda y False so no hay información en la celda 
valor1 = df.Type_1.isin(rango1)

#Obtengo los valores unicos de Type_2
nombre2 = df.Type_2.value_counts()
# Convierto a diccionario el resultado
nombre2 = dict(nombre2)
# Extraigo las claves y las asigno a una lista
rango2 = list(nombre2.keys())
# a valor2 asigno un booleano True encuentra el valor unico en la celda y False so no hay información en la celda 
valor2 = df.Type_2.isin(rango2)

# %%
# al sacar los datos de las casillas que no tienen informacion, alimentamos 
# valor1 y valor2, con True cuando encuentra un tipo de pokemos y False cuando no lo encuentra
# de esta manera hacemos la comparacion que nos da como resultado los pokemosnes que no tienen los dos tipos de pokemon
# alimentando la nueva columna con un False
tamaño = df.shape
doble_tipo = []
for x in np.arange(tamaño[0]):
  if valor1[x] == True and valor2[x] == True:
    doble_tipo.append(True)
  else:
    doble_tipo.append(False)

doble_tipo
df['Doble_tipo'] = doble_tipo

df
# Out:
#       No                   Name   Type_1  Type_2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
'''
12. Muestra las columas Name, Type 1, Type 2 de los pokémon que tienen dos tipos y ordenalos por Type 1 , Type 2 y Name
'''
new_df_doble_tipo = df[df['Doble_tipo'] == True]
dos_tipos = new_df_doble_tipo[['Name', 'Type_1', 'Type_2']]
dos_tipos
# Out:
#                       Name   Type_1  Type_2
# 0                Bulbasaur    Grass  Poison
# 1                  Ivysaur    Grass  Poison
# 2                 Venusaur    Grass  Poison
# 3    VenusaurMega Venusaur    Grass  Poison
# 6                Charizard     Fire  Flying
# ..                     ...      ...     ...
# 795                Diancie     Rock   Fairy
# 796    DiancieMega Diancie     Rock   Fairy
# 797    HoopaHoopa Confined  Psychic   Ghost
# 798     HoopaHoopa Unbound  Psychic    Dark
# 799              Volcanion     Fire   Water
#
# [414 rows x 3 columns]

# %%
from functools import reduce

'''
13. Dada una lista de Artículos con sus precio. Define las siguientes funciones:
Puedes definir más funciones si lo consideras necesario.
'''
articulos = {
    'Camisa': 20,
    'Pantalón': 30,
    'Calcetines': 5,
    'Zapatos': 50,
    'Gorra': 10,
    'Bufanda': 15,
    'Gafas': 25,
    'Reloj': 35,
    'Corbata': 40
}

compra = ['Camisa', 'Pantalón', 'Pantalón', 'Gorra', 'Gafas', 'Corbata']

# %%
# Cómo deseo visualizar bien la información coloco los datos en un dataframe
articulosdf = {'Camisa': [20], 'Pantalón': [30], 'Calcetines': [5], 'Zapatos': [50], 'Gorra': [10], 'Bufanda': [15], 'Gafas': [25], 'Reloj': [35], 'Corbata': [40]}
new_df1 = pd.DataFrame(data=articulosdf)
new_df1
# Out:
#    Camisa  Pantalón  Calcetines  Zapatos  Gorra  Bufanda  Gafas  Reloj  \
# 0      20        30           5       50     10       15     25     35
#
#    Corbata
# 0       40

# %%
# ['Camisa', 'Pantalón', 'Pantalón', 'Gorra', 'Gafas', 'Corbata']

# %%
# A. Una función que calcule el precio total de la compra
def precio(compra, articulos):
  # creo una nueva lista con los valores de los articulos de la compra
  compra_final = []
  for x in compra:
    if x in articulos.keys():
      compra_final.append(articulos[x])
  suma = reduce(lambda x, y: x + y, compra_final, 0)
  return suma

resultado = precio(compra, articulos)
print(f'El Precio total de la compra es: \033[1m{resultado}€.\033[0m')
# Out:
# El Precio total de la compra es: 155€.

# %%
# B. Una función que calcule el precio total de la compra con un descuento del 10%
def descuento(precio):
  valor = (precio - (precio * 0.10))
  return valor

valor_descuento = descuento(resultado)
print(f'El Precio total de la compra con el \033[1m10%\033[0m de descuento es: \033[1m{valor_descuento}€.\033[0m')
# Out:
# El Precio total de la compra con el 10% de descuento es: 139.5€.

# %%
# C. Una función que calcule el precio total de la compra con un descuento del 10% si la compra supera los 100€
def compra_mayor_100(precio):
  if precio > 100:
    valor = (precio - (precio * 0.10))
  else:
    valor = precio
  return valor

valor_descuento = compra_mayor_100(resultado)
print(f'El Precio total de la compra con el \033[1m10%\033[0m de descuento, si la compra es superior a \033[1m100€\033[0m es: \033[1m{valor_descuento}€.\033[0m')
# Out:
# El Precio total de la compra con el 10% de descuento, si la compra es superior a 100€ es: 139.5€.

# %%
# D. Una función que calcule el precio total aplicando el IVA (21%)
def impuesto_iva(precio):
  valor = precio + (precio * 0.21)
  return valor

valor_impuesto = impuesto_iva(resultado)
print(f'El Precio total de la compra con el iva del \033[1m21%\033[0m es: \033[1m{valor_impuesto}€.\033[0m')
# Out:
# El Precio total de la compra con el iva del 21% es: 187.55€.

# %%
# E.lista los artículos cuyo precio es superior a 20€
def precio_mayor_20(articulos):
  new_dic = dict(filter(lambda x: x[1] > 20, articulos.items()))
  return new_dic

articulo_mayor_20 = list(precio_mayor_20(articulos).keys())
articulos_sup_20 = np.array(articulo_mayor_20)
print(f'Los árticulos que superan los \033[1m20€\033[0m son: \033[1m{articulos_sup_20}.\033[0m')
# Out:
# Los árticulos que superan los 20€ son: ['Pantalón' 'Zapatos' 'Gafas' 'Reloj' 'Corbata'].

# %%
'''
14. Dada una lista de tuplas con el nombre de un alumno, apellidos, curso y sus notas. 

 Define una funcion que reciba el curso y saque una lista en la que aparezca el nombre y apellidos y el promedio de sus notas.
 Puedes definir más funciones si lo consideras necesario.
'''

alumnos = [('Juan', 'Pérez', '1', [5, 6, 7, 8, 9]),
            ('Ana', 'García', '2', [5, 6, 7, 8, 9]),
            ('Luis', 'González', '1', [5, 6, 7, 8, 9]),
            ('María', 'Martínez', '2', [5, 6, 7, 8, 9]),
            ('Pedro', 'Rodríguez', '1', [5, 6, 7, 8, 9]),
            ('Lucía', 'Hernández', '2', [5, 6, 7, 8, 9]),
            ('Marta', 'López', '1', [5, 6, 7, 8, 9]),
            ('Sara', 'Díaz', '2', [5, 6, 7, 8, 9]),
            ('Javier', 'Sánchez', '1', [5, 6, 7, 8, 9]),
            ('Miguel', 'Fernández', '2', [5, 6, 7, 8, 9]),
            ('Sergio', 'Jiménez', '1', [5, 6, 7, 8, 9]),
            ('Sandra', 'Ruiz', '2', [5, 6, 7, 8, 9]),
            ('Pablo', 'Álvarez', '1', [5, 6, 7, 8, 9]),
            ('María', 'Gómez', '2', [5, 6, 7, 8, 9]),
]

# %%
# Con Funciones reduce, map y filter
from functools import reduce
def estudio(alumnos):
  i = 0
  promedio = []
  while i < len(alumnos):
    promedio.append(reduce(lambda x,y: x + y, alumnos[i][3],0)/len(alumnos[i][3]))
    i += 1
  
  new_list = list(map(lambda x, y: (x[0], x[1], x[2], y), alumnos, promedio))
  
  dato = ''
  while not dato.isnumeric() or int(dato) not in range(1,3):
    dato = input('Ingrese el curso: ')

  datos = list(filter(lambda x: x[2] == dato, new_list))
  print(f'\nLos alumnos que pertenecen al curso \033[1m{dato}\033[0m son: \n')
  return datos
resultado = estudio(alumnos)
print('\033[1mNOMBRE', 'APELLIDO', 'CURSO', 'PROMEDIO\033[0m')
for i in range(len(resultado)):
  print(resultado[i], end=' ')
  print()
# Out:
# Ingrese el curso: 2
#
# Los alumnos que pertenecen al curso 2 son:
#
# NOMBRE APELLIDO CURSO PROMEDIO
# ('Ana', 'García', '2', 7.0)
# ('María', 'Martínez', '2', 7.0)
# ('Lucía', 'Hernández', '2', 7.0)
# ('Sara', 'Díaz', '2', 7.0)
# ('Miguel', 'Fernández', '2', 7.0)
# ('Sandra', 'Ruiz', '2', 7.0)
# ('María', 'Gómez', '2', 7.0)

# %%
# Con funciones creadas
def estudio1 (alumnos):

  nombres = []
  apellidos = []
  curso = []
  notas = []

  i = 0
  while i < len(alumnos):
    nombres.append(alumnos[i][0])
    apellidos.append(alumnos[i][1])
    curso.append(alumnos[i][2])
    notas.append(alumnos[i][3])
    i += 1
  
  promedio = []
  for x in notas:
    promedio.append(reduce(lambda a,b: a+b, x, 0)/5)

  dato = ''
  while not dato.isnumeric() or int(dato) not in range(1,3):
    dato = input('Ingrese el curso: ')
  
  n_l = []
  for i in range(len(alumnos)):
    if curso[i] == dato:
      n_l.append([nombres[i],apellidos[i],curso[i],promedio[i]])
    else:
      continue
  print(f'\nLos alumnos que pertenecen al curso \033[1m{dato}\033[0m son: \n')  
  return n_l

resultado = estudio1(alumnos)
print('\033[1mNOMBRE', 'APELLIDO', 'CURSO', 'PROMEDIO\033[0m')
for i in range(len(resultado)):
  print(resultado[i], end=' ')
  print()
# Out:
# Ingrese el curso: 1
#
# Los alumnos que pertenecen al curso 1 son:
#
# NOMBRE APELLIDO CURSO PROMEDIO
# ['Juan', 'Pérez', '1', 7.0]
# ['Luis', 'González', '1', 7.0]
# ['Pedro', 'Rodríguez', '1', 7.0]
# ['Marta', 'López', '1', 7.0]
# ['Javier', 'Sánchez', '1', 7.0]
# ['Sergio', 'Jiménez', '1', 7.0]
# ['Pablo', 'Álvarez', '1', 7.0]
